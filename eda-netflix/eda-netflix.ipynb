# %% [markdown]
# # Netflix Movie Dataset

# %%
# import libraries
import kagglehub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
from pathlib import Path

# %%
# ignore warnings in the notebook
import warnings
warnings.filterwarnings('ignore')

# %%
# download dataset
# If running directly inside eda-netflix/, output_dir is "data"
# Otherwise eda-netflix/data from the repo root
data_dir = "data" if Path("data").exists() else "eda-netflix/data"

# Download and extract dataset into the data folder
dataset_path = kagglehub.dataset_download(
    "mjshubham21/movie-dataset-for-analytics-and-visualization",
    output_dir=data_dir
)

print(f"Dataset downloaded to: {dataset_path}")
# Out:
# Dataset downloaded to: data
#    MovieID                         Title        Genre  ReleaseYear  \
# 0        1          Might toward capital       Comedy         2003
# 1        2         He however experience       Comedy         1988
# 2        3  Star responsibility politics       Comedy         1971
# 3        4                  Exactly live       Comedy         1998
# 4        5      Focus improve especially  Documentary         2021
#
#   ReleaseDate Country   BudgetUSD  US_BoxOfficeUSD  Global_BoxOfficeUSD  \
# 0  28-09-2003   China  6577427.79       6613685.82          15472035.66
# 1  14-02-1988     USA  1883810.10       1930949.15           3637731.12
# 2  02-11-1971     USA  2468079.29       4186694.69           7165111.24
# 3  06-08-1998     USA  1447311.46       2023683.92           4373820.26
# 4  17-12-2021   India   900915.86       2129629.10           3113017.38
#
#    Opening_Day_SalesUSD  One_Week_SalesUSD  IMDbRating  RottenTomatoesScore  \
# ...

# %%
# Load the dataset
csv_file = Path(dataset_path) / "movies_dataset.csv"
df = pd.read_csv(csv_file)
df.head()
# Out:
#    MovieID                         Title        Genre  ReleaseYear  \
# 0        1          Might toward capital       Comedy         2003
# 1        2         He however experience       Comedy         1988
# 2        3  Star responsibility politics       Comedy         1971
# 3        4                  Exactly live       Comedy         1998
# 4        5      Focus improve especially  Documentary         2021
#
#   ReleaseDate Country   BudgetUSD  US_BoxOfficeUSD  Global_BoxOfficeUSD  \
# 0  28-09-2003   China  6577427.79       6613685.82          15472035.66
# 1  14-02-1988     USA  1883810.10       1930949.15           3637731.12
# 2  02-11-1971     USA  2468079.29       4186694.69           7165111.24
# 3  06-08-1998     USA  1447311.46       2023683.92           4373820.26
# 4  17-12-2021   India   900915.86       2129629.10           3113017.38
#
#    Opening_Day_SalesUSD  One_Week_SalesUSD  IMDbRating  RottenTomatoesScore  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 999999 entries, 0 to 999998
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   MovieID               999999 non-null  int64
#  1   Title                 999999 non-null  str
#  2   Genre                 999999 non-null  str
#  3   ReleaseYear           999999 non-null  int64
#  4   ReleaseDate           999999 non-null  str
#  5   Country               999999 non-null  str
#  6   BudgetUSD             999999 non-null  float64
#  7   US_BoxOfficeUSD       999999 non-null  float64
#  8   Global_BoxOfficeUSD   999999 non-null  float64
#  9   Opening_Day_SalesUSD  999999 non-null  float64
#  10  One_Week_SalesUSD     999999 non-null  float64
#  11  IMDbRating            999999 non-null  float64
#  12  RottenTomatoesScore   999999 non-null  int64
#  13  NumVotesIMDb          999999 non-null  int64
#  14  NumVotesRT            999999 non-null  int64
# ...

# %%
df.describe()
# Out:
#              MovieID    ReleaseYear     BudgetUSD  US_BoxOfficeUSD  \
# count  999999.000000  999999.000000  9.999990e+05     9.999990e+05
# mean   500000.000000    1998.001220  9.802824e+06     1.496163e+07
# std    288674.990257      19.260863  2.249421e+07     3.879403e+07
# min         1.000000    1950.000000  1.000000e+05     4.002547e+04
# 25%    250000.500000    1984.000000  1.190511e+06     1.489805e+06
# 50%    500000.000000    2001.000000  3.265790e+06     4.388876e+06
# 75%    749999.500000    2014.000000  9.002791e+06     1.287606e+07
# max    999999.000000    2025.000000  3.000000e+08     1.018198e+09
#
#        Global_BoxOfficeUSD  Opening_Day_SalesUSD  One_Week_SalesUSD  \
# count         9.999990e+05          9.999990e+05       9.999990e+05
# mean          2.720625e+07          2.992745e+06       7.483442e+06
# std           6.954294e+07          8.132438e+06       1.955337e+07
# min           1.000000e+05          4.050470e+03       1.650742e+04
# ...

# %%
# Check for null values
df.isna().sum()  # or df.isna().sum().sum()
# Out:
# MovieID                 0
# Title                   0
# Genre                   0
# ReleaseYear             0
# ReleaseDate             0
# Country                 0
# BudgetUSD               0
# US_BoxOfficeUSD         0
# Global_BoxOfficeUSD     0
# Opening_Day_SalesUSD    0
# One_Week_SalesUSD       0
# IMDbRating              0
# RottenTomatoesScore     0
# NumVotesIMDb            0
# NumVotesRT              0
# Director                0
# LeadActor               0
# dtype: int64

# %%
# Check for duplicated values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Get columns and numeric data
df.columns
# Out:
# Index(['MovieID', 'Title', 'Genre', 'ReleaseYear', 'ReleaseDate', 'Country',
#        'BudgetUSD', 'US_BoxOfficeUSD', 'Global_BoxOfficeUSD',
#        'Opening_Day_SalesUSD', 'One_Week_SalesUSD', 'IMDbRating',
#        'RottenTomatoesScore', 'NumVotesIMDb', 'NumVotesRT', 'Director',
#        'LeadActor'],
#       dtype='str')

# %%
num_cols = ['BudgetUSD', 'US_BoxOfficeUSD', 'Global_BoxOfficeUSD',
       'Opening_Day_SalesUSD', 'One_Week_SalesUSD', 'IMDbRating',
       'RottenTomatoesScore', 'NumVotesIMDb', 'NumVotesRT']

# %%
# Visualize Distributions of each numeric column
for col in num_cols:
    ax = sns.histplot(df[col], bins=50, kde=True)
    ax.lines[0].set_color('red')
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Distribution of categorical features
categorical_cols = ['Genre', 'Country', 'Director', 'LeadActor']

# %%
for col in categorical_cols:
    df[col].value_counts().head(20).plot(kind='bar')
    plt.title(f'Top 20 {col}')
    plt.show()

# %%
# Correlations

df.columns
# Out:
# Index(['MovieID', 'Title', 'Genre', 'ReleaseYear', 'ReleaseDate', 'Country',
#        'BudgetUSD', 'US_BoxOfficeUSD', 'Global_BoxOfficeUSD',
#        'Opening_Day_SalesUSD', 'One_Week_SalesUSD', 'IMDbRating',
#        'RottenTomatoesScore', 'NumVotesIMDb', 'NumVotesRT', 'Director',
#        'LeadActor'],
#       dtype='str')

# %%
sns.scatterplot(data=df, x='BudgetUSD', y='Global_BoxOfficeUSD', alpha=0.3)
plt.title('BudgetUSD VS Global Box Office USD')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
sns.scatterplot(data=df, x='IMDbRating', y='RottenTomatoesScore', alpha=0.3)
plt.title('IMDb VS Rotten Tomatoes Ratings')
# Out:
# Text(0.5, 1.0, 'IMDb VS Rotten Tomatoes Ratings')

# %%
genre_year_stats = df.groupby(['Genre', 'ReleaseYear']).agg({
    'Global_BoxOfficeUSD': 'mean',
    'BudgetUSD': 'mean',
    'IMDbRating': 'mean',
    'RottenTomatoesScore': 'mean'
}).reset_index()

# %%
genre_year_stats
# Out:
#         Genre  ReleaseYear  Global_BoxOfficeUSD     BudgetUSD  IMDbRating  \
# 0      Action         1950         2.897931e+07  1.011213e+07    6.361671
# 1      Action         1951         2.896091e+07  1.027247e+07    6.546575
# 2      Action         1952         2.789712e+07  9.683596e+06    6.487152
# 3      Action         1953         2.762857e+07  9.471222e+06    6.387726
# 4      Action         1954         3.244328e+07  1.054447e+07    6.511553
# ..        ...          ...                  ...           ...         ...
# 603  Thriller         2021         2.859975e+07  1.012603e+07    6.477995
# 604  Thriller         2022         2.670292e+07  9.452524e+06    6.466554
# 605  Thriller         2023         2.694591e+07  9.877671e+06    6.527363
# 606  Thriller         2024         2.576942e+07  9.764218e+06    6.490901
# 607  Thriller         2025         2.595418e+07  9.668806e+06    6.535658
#
#      RottenTomatoesScore
# 0              63.564841
# 1              65.671233
# ...

# %%
# Global Box Office by Genre over Years
plt.figure(figsize=(15,10))
sns.lineplot(data=genre_year_stats, x='ReleaseYear', y='Global_BoxOfficeUSD', hue='Genre')
plt.title('Average Global Box Office by Genre over Years')
plt.show()

# %%
# Average Global Box Office of Genre "Action" over Years
plt.figure(figsize=(15,10))
sns.lineplot(data=genre_year_stats.query("Genre == 'Action'"), x='ReleaseYear', y='Global_BoxOfficeUSD', hue='Genre')
plt.title('Average Global Box Office of Genre "Action" over Years')
plt.show()

# %%
top_actors = df.groupby('LeadActor')['IMDbRating'].mean().sort_values(ascending=False).head(10)

# %%
top_actors
# Out:
# LeadActor
# Meghan Mcintosh     6.566255
# Meghan Johnson      6.556890
# Carla Dougherty     6.554450
# Jeffrey Haley       6.553223
# Jennifer Cook       6.551508
# Brandon Davidson    6.551028
# Krystal Cross       6.547780
# Morgan King         6.546569
# Anthony Cross       6.546377
# Stephanie Moore     6.546206
# Name: IMDbRating, dtype: float64

# %%
top_actors.plot(kind='bar')
plt.title('Top 10 Actors by AVG IMDb Rating')
# Out:
# Text(0.5, 1.0, 'Top 10 Actors by AVG IMDb Rating')

# %%
# 50 Top Actors
plt.figure(figsize=(10,6))
top_actors_50 = df.groupby('LeadActor')['IMDbRating'].mean().sort_values(ascending=False).head(50)
top_actors_50.plot(kind='bar')
plt.title('Top 50 Actors by AVG IMDb Rating')
# Out:
# Text(0.5, 1.0, 'Top 50 Actors by AVG IMDb Rating')
